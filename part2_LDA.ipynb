# %%
import spacy
import gensim
from gensim import corpora
from gensim.test.utils import datapath
nlp = spacy.load( "en_core_web_sm", disable=["parser", "ner"] )
import pandas

# %%
data = pandas.read_csv( 'CHI.tsv', sep='\t', header=0 )
data['TEXT'] = data['TITLE'] + '. ' + data['ABSTRACT']
data
# Out:
#       YEAR                                              TITLE  \
# 0     2000                  Intelligent gaze-added interfaces
# 1     2000                 Evaluation of eye gaze interaction
# 2     2000  Enriching buyers' experiences: the SmartClient...
# 3     2000  Quality is in the eye of the beholder: meeting...
# 4     2000  What makes Internet users visit cyber stores a...
# ...    ...                                                ...
# 4061  1999  Mutual disambiguation of recognition errors in...
# 4062  1999  Model-based and empirical evaluation of multim...
# 4063  1999  Cooperative inquiry: developing new technologi...
# 4064  1999  Projected realities: conceptual design for cul...
# 4065  1999  Customer-focused design data in a large, multi...
#
#                                                ABSTRACT  \
# 0     We discuss a novel type of interface, the inte...
# 1     Eye gaze interaction can provide a convenient ...
# 2     In electronic commerce, a satisfying buyer exp...
# 3     Growing usage and diversity of applications on...
# 4     Retaining customer loyalty is crucial in elect...
# ...                                                 ...
# 4061  As a new generation of multimodal/media system...
# 4062  Our research addresses the problem of error co...
# 4063  In todays homes and schools, children are emer...
# 4064  As a part of a European Union sponsored projec...
# 4065  Qualitative user-centered design processes suc...
#
#                                                    TEXT
# 0     Intelligent gaze-added interfaces. We discuss ...
# 1     Evaluation of eye gaze interaction. Eye gaze i...
# 2     Enriching buyers' experiences: the SmartClient...
# 3     Quality is in the eye of the beholder: meeting...
# 4     What makes Internet users visit cyber stores a...
# ...                                                 ...
# 4061  Mutual disambiguation of recognition errors in...
# 4062  Model-based and empirical evaluation of multim...
# 4063  Cooperative inquiry: developing new technologi...
# 4064  Projected realities: conceptual design for cul...
# 4065  Customer-focused design data in a large, multi...
#
# [4066 rows x 4 columns]

# %%
# process a raw text and returns a list of processed word tokens (removes stopwords and punctuations, applies casefolding and stemming)
def text2words(rawtext, nlp):
    text = nlp(rawtext)
    return [ token.lemma_.lower() for token in text if not token.is_stop and not token.is_punct ]

# %%
voc = corpora.Dictionary.load( "HCI_topics.id2word" ) # load the dictionary (note it is a file ends with .id2word)
lda = gensim.models.ldamulticore.LdaMulticore.load( "HCI_topics" ) # load the model
lda.num_topics
# Out:
# 20

# %%
def label_topic(lda, topicid, numwords):
    # write your solution here and change the return value None
    a = lda.show_topic(topicid,numwords)
    #print(a)
    b = [i[0] for i in a]
    #print(b)
    b = " ".join(b)
    b = str(topicid) + ": "+b
    #print(b)
    return b
#label_topic(lda, 0, 5)

# %%
topic_labels = { i:label_topic(lda, i, 10) for i in range(lda.num_topics) }
topic_labels
# Out:
# {0: '0: user direct technique manipulation combination control point drawing edit alternative',
#  1: '1: model eye pointing task device movement law input gaze fitts',
#  2: '2: system user computer language human error use behavior problem usability',
#  3: '3: voice usability user whisper labeling trace visualization technique annotation problem',
#  4: '4: object physical interaction user computer interface interactive application tool system',
#  5: '5: virtual focus space 3d interface environment design user navigation view',
#  6: '6: display technique study screen target interaction image present provide visual',
#  7: '7: web user search information site page tool task datum system',
#  8: '8: device touch gesture input interaction hand user sensor finger technique',
#  9: '9: child interactive computer support study blind design work base present',
#  10: '10: game video play online experience player adult group motion content',
#  11: '11: design process note child new technology group support work system',
#  12: '12: audio recognition speech correction multimodal system user error study result',
#  13: '13: user menu application task time visual system performance design model',
#  14: '14: user task result study participant performance time experiment effect find',
#  15: '15: mobile user phone feedback study base use location application photo',
#  16: '16: system communication video support collaboration speaker work people remote native',
#  17: '17: design social study technology paper research people use interaction activity',
#  18: '18: datum document information tag reader text paper electronic representation read',
#  19: '19: interface design user application base system interaction tangible context computer'}

# %%
def yearly_topic_distribution(data, lda, voc, year):
    corpus = [ text2words(text, nlp) for text in data['TEXT'] ]
    corpusbow = [ voc.doc2bow(text) for text in corpus ]
    k = len(data[data.YEAR == year])
    i = 0
    Dict = {}
    while i < lda.num_topics:
        j = 0
        sm = 0
        for ind in data.index:
            if data["YEAR"][ind] == year:
                a = lda.get_document_topics( corpusbow[j] )
                b = [item for item in a if item[0] == i]
                if len(b) == 0:
                    sm += 0
                elif len(b) > 1:
                    sm += b[0][1]
                    print("ohh no")
                else:
                    sm += b[0][1]
            j += 1    
        sm = sm/k
        Dict[i] = sm
        i += 1
        
            
    return Dict

# %%
topic_distribution_1981 = yearly_topic_distribution(data, lda, voc, 1981)
topic_distribution_1981
# Out:
# {0: 0.029011486423394038,
#  1: 0.010491815883488883,
#  2: 0.17919602836408313,
#  3: 0.016036028278962014,
#  4: 0.0227440336039142,
#  5: 0.007873928292639672,
#  6: 0.05180557453561397,
#  7: 0.07625057019056782,
#  8: 0.004128195271487274,
#  9: 0.028900657558724993,
#  10: 0.017510275223425457,
#  11: 0.03426610999223259,
#  12: 0.019470258098509576,
#  13: 0.042369348854417836,
#  14: 0.08665443658237419,
#  15: 0.021665934517624833,
#  16: 0.008840651901823187,
#  17: 0.2367381447305282,
#  18: 0.06172846872655172,
#  19: 0.03645298510257687}

# %%
def overall_topic_distribution(data, lda, voc):
    corpus = [ text2words(text, nlp) for text in data['TEXT'] ]
    corpusbow = [ voc.doc2bow(text) for text in corpus ]
    k = len(data)
    i = 0
    Dict = {}
    while i < lda.num_topics:
        j = 0
        sm = 0
        for ind in data.index:
            a = lda.get_document_topics( corpusbow[j] )
            b = [item for item in a if item[0] == i]
            if len(b) == 0:
                sm += 0
            elif len(b) > 1:
                sm += b[0][1]
                print("ohh no")
            else:
                sm += b[0][1]
            j += 1    
        sm = sm/k
        Dict[i] = sm
        i += 1
        
            
    return Dict
overall_topics = overall_topic_distribution(data, lda, voc)
overall_topics
# Out:
# {0: 0.017821197067943998,
#  1: 0.026913130198698353,
#  2: 0.08070328262044997,
#  3: 0.019322453295987006,
#  4: 0.027010779502809387,
#  5: 0.02116953704824082,
#  6: 0.07979075324369353,
#  7: 0.050218198942025116,
#  8: 0.02881852178607618,
#  9: 0.021826257970893232,
#  10: 0.03025083334574112,
#  11: 0.03937601166939023,
#  12: 0.01490110794377302,
#  13: 0.03559428495155676,
#  14: 0.10884855093894388,
#  15: 0.05872894534099054,
#  16: 0.033792859956895155,
#  17: 0.2348402797439641,
#  18: 0.021771096754764182,
#  19: 0.03973472668925384}

# %%
yearly_topics = { 'Total': list(overall_topics.values()) }
for year in sorted(data['YEAR'].unique()):
    yearly_topics[str(year)] = list( yearly_topic_distribution(data, lda, voc, year).values() )
results = pandas.DataFrame(data=yearly_topics).rename( index=topic_labels )
results
# Out:
#                                                        Total      1981  \
# 0: user direct technique manipulation combinati...  0.017821  0.028995
# 1: model eye pointing task device movement law ...  0.026913  0.011361
# 2: system user computer language human error us...  0.080703  0.179329
# 3: voice usability user whisper labeling trace ...  0.019322  0.016036
# 4: object physical interaction user computer in...  0.027011  0.023605
# 5: virtual focus space 3d interface environment...  0.021170  0.007874
# 6: display technique study screen target intera...  0.079791  0.051794
# 7: web user search information site page tool t...  0.050218  0.076250
# 8: device touch gesture input interaction hand ...  0.028819  0.004128
# 9: child interactive computer support study bli...  0.021826  0.028779
# 10: game video play online experience player ad...  0.030251  0.017510
# 11: design process note child new technology gr...  0.039376  0.034277
# 12: audio recognition speech correction multimo...  0.014901  0.019489
# 13: user menu application task time visual syst...  0.035594  0.042448
# 14: user task result study participant performa...  0.108849  0.086530
# 15: mobile user phone feedback study base use l...  0.058729  0.021700
# 16: system communication video support collabor...  0.033793  0.008841
# 17: design social study technology paper resear...  0.234840  0.236423
# 18: datum document information tag reader text ...  0.021771  0.061743
# 19: interface design user application base syst...  0.039735  0.036455
#
#                                                         1982      1983  \
# 0: user direct technique manipulation combinati...  0.029791  0.029347
# 1: model eye pointing task device movement law ...  0.015779  0.016460
# 2: system user computer language human error us...  0.251011  0.247499
# 3: voice usability user whisper labeling trace ...  0.012657  0.017660
# 4: object physical interaction user computer in...  0.020385  0.029273
# 5: virtual focus space 3d interface environment...  0.006013  0.012197
# 6: display technique study screen target intera...  0.038180  0.073331
# 7: web user search information site page tool t...  0.037414  0.042798
# 8: device touch gesture input interaction hand ...  0.006134  0.003820
# 9: child interactive computer support study bli...  0.033907  0.026549
# 10: game video play online experience player ad...  0.011163  0.015115
# 11: design process note child new technology gr...  0.041751  0.028848
# 12: audio recognition speech correction multimo...  0.011432  0.014893
# 13: user menu application task time visual syst...  0.045070  0.038319
# 14: user task result study participant performa...  0.116237  0.165163
# 15: mobile user phone feedback study base use l...  0.021576  0.011424
# 16: system communication video support collabor...  0.018878  0.016786
# 17: design social study technology paper resear...  0.177899  0.137802
# 18: datum document information tag reader text ...  0.035825  0.022343
# 19: interface design user application base syst...  0.059196  0.041903
#
#                                                         1985      1986  \
# 0: user direct technique manipulation combinati...  0.032474  0.032253
# 1: model eye pointing task device movement law ...  0.039749  0.016440
# 2: system user computer language human error us...  0.217451  0.220887
# 3: voice usability user whisper labeling trace ...  0.014820  0.026191
# 4: object physical interaction user computer in...  0.022223  0.025689
# 5: virtual focus space 3d interface environment...  0.008508  0.008391
# 6: display technique study screen target intera...  0.069458  0.059668
# 7: web user search information site page tool t...  0.034620  0.044306
# 8: device touch gesture input interaction hand ...  0.017896  0.016126
# 9: child interactive computer support study bli...  0.016021  0.036679
# 10: game video play online experience player ad...  0.005706  0.008046
# 11: design process note child new technology gr...  0.026891  0.026591
# 12: audio recognition speech correction multimo...  0.032361  0.020786
# 13: user menu application task time visual syst...  0.044855  0.043581
# 14: user task result study participant performa...  0.130173  0.122202
# 15: mobile user phone feedback study base use l...  0.021715  0.018696
# 16: system communication video support collabor...  0.025290  0.010377
# 17: design social study technology paper resear...  0.142281  0.135478
# 18: datum document information tag reader text ...  0.030268  0.025559
# 19: interface design user application base syst...  0.056792  0.089134
#
#                                                         1987      1988  \
# 0: user direct technique manipulation combinati...  0.038121  0.037700
# 1: model eye pointing task device movement law ...  0.040509  0.021396
# 2: system user computer language human error us...  0.129566  0.180947
# 3: voice usability user whisper labeling trace ...  0.017251  0.019865
# 4: object physical interaction user computer in...  0.018467  0.031686
# 5: virtual focus space 3d interface environment...  0.013362  0.024508
# 6: display technique study screen target intera...  0.094265  0.074544
# 7: web user search information site page tool t...  0.042613  0.062445
# 8: device touch gesture input interaction hand ...  0.011570  0.008365
# 9: child interactive computer support study bli...  0.028510  0.029946
# 10: game video play online experience player ad...  0.012975  0.015245
# 11: design process note child new technology gr...  0.040827  0.024428
# 12: audio recognition speech correction multimo...  0.015013  0.014259
# 13: user menu application task time visual syst...  0.026339  0.069624
# 14: user task result study participant performa...  0.152371  0.117824
# 15: mobile user phone feedback study base use l...  0.008166  0.013789
# 16: system communication video support collabor...  0.020382  0.013020
# 17: design social study technology paper resear...  0.187160  0.131294
# 18: datum document information tag reader text ...  0.007127  0.013152
# 19: interface design user application base syst...  0.087243  0.084621
#
#                                                         1989      1990  ...  \
# 0: user direct technique manipulation combinati...  0.029334  0.024742  ...
# 1: model eye pointing task device movement law ...  0.023806  0.050912  ...
# 2: system user computer language human error us...  0.161653  0.183297  ...
# 3: voice usability user whisper labeling trace ...  0.025158  0.020737  ...
# 4: object physical interaction user computer in...  0.035640  0.023491  ...
# 5: virtual focus space 3d interface environment...  0.024881  0.010515  ...
# 6: display technique study screen target intera...  0.055352  0.053479  ...
# 7: web user search information site page tool t...  0.039935  0.020804  ...
# 8: device touch gesture input interaction hand ...  0.016688  0.013184  ...
# 9: child interactive computer support study bli...  0.024908  0.026574  ...
# 10: game video play online experience player ad...  0.003691  0.004315  ...
# 11: design process note child new technology gr...  0.032386  0.049496  ...
# 12: audio recognition speech correction multimo...  0.016310  0.011918  ...
# 13: user menu application task time visual syst...  0.046475  0.060550  ...
# 14: user task result study participant performa...  0.107342  0.071840  ...
# 15: mobile user phone feedback study base use l...  0.018828  0.016905  ...
# 16: system communication video support collabor...  0.039804  0.022559  ...
# 17: design social study technology paper resear...  0.149790  0.197271  ...
# 18: datum document information tag reader text ...  0.029573  0.022281  ...
# 19: interface design user application base syst...  0.107802  0.105145  ...
#
#                                                         2005      2006  \
# 0: user direct technique manipulation combinati...  0.014090  0.019578
# 1: model eye pointing task device movement law ...  0.038985  0.024488
# 2: system user computer language human error us...  0.069058  0.066008
# 3: voice usability user whisper labeling trace ...  0.028931  0.029943
# 4: object physical interaction user computer in...  0.025704  0.031144
# 5: virtual focus space 3d interface environment...  0.016789  0.019289
# 6: display technique study screen target intera...  0.097069  0.090238
# 7: web user search information site page tool t...  0.039305  0.062929
# 8: device touch gesture input interaction hand ...  0.020446  0.023870
# 9: child interactive computer support study bli...  0.023817  0.013377
# 10: game video play online experience player ad...  0.016756  0.031460
# 11: design process note child new technology gr...  0.044665  0.033571
# 12: audio recognition speech correction multimo...  0.008481  0.016479
# 13: user menu application task time visual syst...  0.034014  0.041923
# 14: user task result study participant performa...  0.128787  0.116979
# 15: mobile user phone feedback study base use l...  0.067452  0.069420
# 16: system communication video support collabor...  0.047489  0.042363
# 17: design social study technology paper resear...  0.222582  0.199769
# 18: datum document information tag reader text ...  0.017332  0.018637
# 19: interface design user application base syst...  0.030298  0.040368
#
#                                                         2007      2008  \
# 0: user direct technique manipulation combinati...  0.018024  0.016841
# 1: model eye pointing task device movement law ...  0.036701  0.030667
# 2: system user computer language human error us...  0.065969  0.061561
# 3: voice usability user whisper labeling trace ...  0.018693  0.016106
# 4: object physical interaction user computer in...  0.028772  0.021595
# 5: virtual focus space 3d interface environment...  0.017568  0.020468
# 6: display technique study screen target intera...  0.088269  0.095269
# 7: web user search information site page tool t...  0.053236  0.068440
# 8: device touch gesture input interaction hand ...  0.028990  0.026927
# 9: child interactive computer support study bli...  0.017394  0.021802
# 10: game video play online experience player ad...  0.031067  0.022473
# 11: design process note child new technology gr...  0.030915  0.038175
# 12: audio recognition speech correction multimo...  0.014573  0.011062
# 13: user menu application task time visual syst...  0.038360  0.043062
# 14: user task result study participant performa...  0.126876  0.105741
# 15: mobile user phone feedback study base use l...  0.060991  0.069449
# 16: system communication video support collabor...  0.045775  0.032192
# 17: design social study technology paper resear...  0.218918  0.236515
# 18: datum document information tag reader text ...  0.015129  0.027199
# 19: interface design user application base syst...  0.035362  0.025988
#
#                                                         2009      2010  \
# 0: user direct technique manipulation combinati...  0.014388  0.012542
# 1: model eye pointing task device movement law ...  0.022928  0.026070
# 2: system user computer language human error us...  0.050566  0.061655
# 3: voice usability user whisper labeling trace ...  0.020150  0.017571
# 4: object physical interaction user computer in...  0.025161  0.018795
# 5: virtual focus space 3d interface environment...  0.019542  0.023180
# 6: display technique study screen target intera...  0.084952  0.068186
# 7: web user search information site page tool t...  0.061760  0.050122
# 8: device touch gesture input interaction hand ...  0.023162  0.026206
# 9: child interactive computer support study bli...  0.018348  0.023178
# 10: game video play online experience player ad...  0.031615  0.039466
# 11: design process note child new technology gr...  0.039495  0.042225
# 12: audio recognition speech correction multimo...  0.015520  0.015346
# 13: user menu application task time visual syst...  0.032928  0.028266
# 14: user task result study participant performa...  0.097439  0.116417
# 15: mobile user phone feedback study base use l...  0.071195  0.071161
# 16: system communication video support collabor...  0.039874  0.033209
# 17: design social study technology paper resear...  0.271270  0.270272
# 18: datum document information tag reader text ...  0.020638  0.023040
# 19: interface design user application base syst...  0.030166  0.024602
#
#                                                         2011      2012  \
# 0: user direct technique manipulation combinati...  0.014453  0.013217
# 1: model eye pointing task device movement law ...  0.024838  0.019683
# 2: system user computer language human error us...  0.052192  0.055951
# 3: voice usability user whisper labeling trace ...  0.015735  0.017681
# 4: object physical interaction user computer in...  0.021981  0.024626
# 5: virtual focus space 3d interface environment...  0.019469  0.022570
# 6: display technique study screen target intera...  0.083230  0.084911
# 7: web user search information site page tool t...  0.045481  0.049391
# 8: device touch gesture input interaction hand ...  0.039139  0.038917
# 9: child interactive computer support study bli...  0.021341  0.023892
# 10: game video play online experience player ad...  0.033312  0.038338
# 11: design process note child new technology gr...  0.036882  0.041344
# 12: audio recognition speech correction multimo...  0.012719  0.011488
# 13: user menu application task time visual syst...  0.023867  0.027282
# 14: user task result study participant performa...  0.107003  0.108926
# 15: mobile user phone feedback study base use l...  0.075524  0.074494
# 16: system communication video support collabor...  0.036793  0.030989
# 17: design social study technology paper resear...  0.278658  0.258245
# 18: datum document information tag reader text ...  0.021020  0.021867
# 19: interface design user application base syst...  0.028609  0.028975
#
#                                                         2013      2014
# 0: user direct technique manipulation combinati...  0.012808  0.012872
# 1: model eye pointing task device movement law ...  0.022925  0.022395
# 2: system user computer language human error us...  0.049292  0.047576
# 3: voice usability user whisper labeling trace ...  0.015308  0.019451
# 4: object physical interaction user computer in...  0.023160  0.023590
# 5: virtual focus space 3d interface environment...  0.018278  0.020039
# 6: display technique study screen target intera...  0.082791  0.083692
# 7: web user search information site page tool t...  0.038121  0.041882
# 8: device touch gesture input interaction hand ...  0.043147  0.043931
# 9: child interactive computer support study bli...  0.017207  0.021011
# 10: game video play online experience player ad...  0.039376  0.046468
# 11: design process note child new technology gr...  0.042759  0.036550
# 12: audio recognition speech correction multimo...  0.011337  0.010098
# 13: user menu application task time visual syst...  0.027634  0.030389
# 14: user task result study participant performa...  0.106009  0.111505
# 15: mobile user phone feedback study base use l...  0.069649  0.072908
# 16: system communication video support collabor...  0.026764  0.030098
# 17: design social study technology paper resear...  0.300682  0.273909
# 18: datum document information tag reader text ...  0.018994  0.018577
# 19: interface design user application base syst...  0.025763  0.025428
#
# [20 rows x 29 columns]

# %%
# Then, let's sort the topics by their overall distribution (the 'Total' column)
results.sort_values(by=['Total'], ascending=False)
# Out:
#                                                        Total      1981  \
# 17: design social study technology paper resear...  0.234840  0.236423
# 14: user task result study participant performa...  0.108849  0.086530
# 2: system user computer language human error us...  0.080703  0.179329
# 6: display technique study screen target intera...  0.079791  0.051794
# 15: mobile user phone feedback study base use l...  0.058729  0.021700
# 7: web user search information site page tool t...  0.050218  0.076250
# 19: interface design user application base syst...  0.039735  0.036455
# 11: design process note child new technology gr...  0.039376  0.034277
# 13: user menu application task time visual syst...  0.035594  0.042448
# 16: system communication video support collabor...  0.033793  0.008841
# 10: game video play online experience player ad...  0.030251  0.017510
# 8: device touch gesture input interaction hand ...  0.028819  0.004128
# 4: object physical interaction user computer in...  0.027011  0.023605
# 1: model eye pointing task device movement law ...  0.026913  0.011361
# 9: child interactive computer support study bli...  0.021826  0.028779
# 18: datum document information tag reader text ...  0.021771  0.061743
# 5: virtual focus space 3d interface environment...  0.021170  0.007874
# 3: voice usability user whisper labeling trace ...  0.019322  0.016036
# 0: user direct technique manipulation combinati...  0.017821  0.028995
# 12: audio recognition speech correction multimo...  0.014901  0.019489
#
#                                                         1982      1983  \
# 17: design social study technology paper resear...  0.177899  0.137802
# 14: user task result study participant performa...  0.116237  0.165163
# 2: system user computer language human error us...  0.251011  0.247499
# 6: display technique study screen target intera...  0.038180  0.073331
# 15: mobile user phone feedback study base use l...  0.021576  0.011424
# 7: web user search information site page tool t...  0.037414  0.042798
# 19: interface design user application base syst...  0.059196  0.041903
# 11: design process note child new technology gr...  0.041751  0.028848
# 13: user menu application task time visual syst...  0.045070  0.038319
# 16: system communication video support collabor...  0.018878  0.016786
# 10: game video play online experience player ad...  0.011163  0.015115
# 8: device touch gesture input interaction hand ...  0.006134  0.003820
# 4: object physical interaction user computer in...  0.020385  0.029273
# 1: model eye pointing task device movement law ...  0.015779  0.016460
# 9: child interactive computer support study bli...  0.033907  0.026549
# 18: datum document information tag reader text ...  0.035825  0.022343
# 5: virtual focus space 3d interface environment...  0.006013  0.012197
# 3: voice usability user whisper labeling trace ...  0.012657  0.017660
# 0: user direct technique manipulation combinati...  0.029791  0.029347
# 12: audio recognition speech correction multimo...  0.011432  0.014893
#
#                                                         1985      1986  \
# 17: design social study technology paper resear...  0.142281  0.135478
# 14: user task result study participant performa...  0.130173  0.122202
# 2: system user computer language human error us...  0.217451  0.220887
# 6: display technique study screen target intera...  0.069458  0.059668
# 15: mobile user phone feedback study base use l...  0.021715  0.018696
# 7: web user search information site page tool t...  0.034620  0.044306
# 19: interface design user application base syst...  0.056792  0.089134
# 11: design process note child new technology gr...  0.026891  0.026591
# 13: user menu application task time visual syst...  0.044855  0.043581
# 16: system communication video support collabor...  0.025290  0.010377
# 10: game video play online experience player ad...  0.005706  0.008046
# 8: device touch gesture input interaction hand ...  0.017896  0.016126
# 4: object physical interaction user computer in...  0.022223  0.025689
# 1: model eye pointing task device movement law ...  0.039749  0.016440
# 9: child interactive computer support study bli...  0.016021  0.036679
# 18: datum document information tag reader text ...  0.030268  0.025559
# 5: virtual focus space 3d interface environment...  0.008508  0.008391
# 3: voice usability user whisper labeling trace ...  0.014820  0.026191
# 0: user direct technique manipulation combinati...  0.032474  0.032253
# 12: audio recognition speech correction multimo...  0.032361  0.020786
#
#                                                         1987      1988  \
# 17: design social study technology paper resear...  0.187160  0.131294
# 14: user task result study participant performa...  0.152371  0.117824
# 2: system user computer language human error us...  0.129566  0.180947
# 6: display technique study screen target intera...  0.094265  0.074544
# 15: mobile user phone feedback study base use l...  0.008166  0.013789
# 7: web user search information site page tool t...  0.042613  0.062445
# 19: interface design user application base syst...  0.087243  0.084621
# 11: design process note child new technology gr...  0.040827  0.024428
# 13: user menu application task time visual syst...  0.026339  0.069624
# 16: system communication video support collabor...  0.020382  0.013020
# 10: game video play online experience player ad...  0.012975  0.015245
# 8: device touch gesture input interaction hand ...  0.011570  0.008365
# 4: object physical interaction user computer in...  0.018467  0.031686
# 1: model eye pointing task device movement law ...  0.040509  0.021396
# 9: child interactive computer support study bli...  0.028510  0.029946
# 18: datum document information tag reader text ...  0.007127  0.013152
# 5: virtual focus space 3d interface environment...  0.013362  0.024508
# 3: voice usability user whisper labeling trace ...  0.017251  0.019865
# 0: user direct technique manipulation combinati...  0.038121  0.037700
# 12: audio recognition speech correction multimo...  0.015013  0.014259
#
#                                                         1989      1990  ...  \
# 17: design social study technology paper resear...  0.149790  0.197271  ...
# 14: user task result study participant performa...  0.107342  0.071840  ...
# 2: system user computer language human error us...  0.161653  0.183297  ...
# 6: display technique study screen target intera...  0.055352  0.053479  ...
# 15: mobile user phone feedback study base use l...  0.018828  0.016905  ...
# 7: web user search information site page tool t...  0.039935  0.020804  ...
# 19: interface design user application base syst...  0.107802  0.105145  ...
# 11: design process note child new technology gr...  0.032386  0.049496  ...
# 13: user menu application task time visual syst...  0.046475  0.060550  ...
# 16: system communication video support collabor...  0.039804  0.022559  ...
# 10: game video play online experience player ad...  0.003691  0.004315  ...
# 8: device touch gesture input interaction hand ...  0.016688  0.013184  ...
# 4: object physical interaction user computer in...  0.035640  0.023491  ...
# 1: model eye pointing task device movement law ...  0.023806  0.050912  ...
# 9: child interactive computer support study bli...  0.024908  0.026574  ...
# 18: datum document information tag reader text ...  0.029573  0.022281  ...
# 5: virtual focus space 3d interface environment...  0.024881  0.010515  ...
# 3: voice usability user whisper labeling trace ...  0.025158  0.020737  ...
# 0: user direct technique manipulation combinati...  0.029334  0.024742  ...
# 12: audio recognition speech correction multimo...  0.016310  0.011918  ...
#
#                                                         2005      2006  \
# 17: design social study technology paper resear...  0.222582  0.199769
# 14: user task result study participant performa...  0.128787  0.116979
# 2: system user computer language human error us...  0.069058  0.066008
# 6: display technique study screen target intera...  0.097069  0.090238
# 15: mobile user phone feedback study base use l...  0.067452  0.069420
# 7: web user search information site page tool t...  0.039305  0.062929
# 19: interface design user application base syst...  0.030298  0.040368
# 11: design process note child new technology gr...  0.044665  0.033571
# 13: user menu application task time visual syst...  0.034014  0.041923
# 16: system communication video support collabor...  0.047489  0.042363
# 10: game video play online experience player ad...  0.016756  0.031460
# 8: device touch gesture input interaction hand ...  0.020446  0.023870
# 4: object physical interaction user computer in...  0.025704  0.031144
# 1: model eye pointing task device movement law ...  0.038985  0.024488
# 9: child interactive computer support study bli...  0.023817  0.013377
# 18: datum document information tag reader text ...  0.017332  0.018637
# 5: virtual focus space 3d interface environment...  0.016789  0.019289
# 3: voice usability user whisper labeling trace ...  0.028931  0.029943
# 0: user direct technique manipulation combinati...  0.014090  0.019578
# 12: audio recognition speech correction multimo...  0.008481  0.016479
#
#                                                         2007      2008  \
# 17: design social study technology paper resear...  0.218918  0.236515
# 14: user task result study participant performa...  0.126876  0.105741
# 2: system user computer language human error us...  0.065969  0.061561
# 6: display technique study screen target intera...  0.088269  0.095269
# 15: mobile user phone feedback study base use l...  0.060991  0.069449
# 7: web user search information site page tool t...  0.053236  0.068440
# 19: interface design user application base syst...  0.035362  0.025988
# 11: design process note child new technology gr...  0.030915  0.038175
# 13: user menu application task time visual syst...  0.038360  0.043062
# 16: system communication video support collabor...  0.045775  0.032192
# 10: game video play online experience player ad...  0.031067  0.022473
# 8: device touch gesture input interaction hand ...  0.028990  0.026927
# 4: object physical interaction user computer in...  0.028772  0.021595
# 1: model eye pointing task device movement law ...  0.036701  0.030667
# 9: child interactive computer support study bli...  0.017394  0.021802
# 18: datum document information tag reader text ...  0.015129  0.027199
# 5: virtual focus space 3d interface environment...  0.017568  0.020468
# 3: voice usability user whisper labeling trace ...  0.018693  0.016106
# 0: user direct technique manipulation combinati...  0.018024  0.016841
# 12: audio recognition speech correction multimo...  0.014573  0.011062
#
#                                                         2009      2010  \
# 17: design social study technology paper resear...  0.271270  0.270272
# 14: user task result study participant performa...  0.097439  0.116417
# 2: system user computer language human error us...  0.050566  0.061655
# 6: display technique study screen target intera...  0.084952  0.068186
# 15: mobile user phone feedback study base use l...  0.071195  0.071161
# 7: web user search information site page tool t...  0.061760  0.050122
# 19: interface design user application base syst...  0.030166  0.024602
# 11: design process note child new technology gr...  0.039495  0.042225
# 13: user menu application task time visual syst...  0.032928  0.028266
# 16: system communication video support collabor...  0.039874  0.033209
# 10: game video play online experience player ad...  0.031615  0.039466
# 8: device touch gesture input interaction hand ...  0.023162  0.026206
# 4: object physical interaction user computer in...  0.025161  0.018795
# 1: model eye pointing task device movement law ...  0.022928  0.026070
# 9: child interactive computer support study bli...  0.018348  0.023178
# 18: datum document information tag reader text ...  0.020638  0.023040
# 5: virtual focus space 3d interface environment...  0.019542  0.023180
# 3: voice usability user whisper labeling trace ...  0.020150  0.017571
# 0: user direct technique manipulation combinati...  0.014388  0.012542
# 12: audio recognition speech correction multimo...  0.015520  0.015346
#
#                                                         2011      2012  \
# 17: design social study technology paper resear...  0.278658  0.258245
# 14: user task result study participant performa...  0.107003  0.108926
# 2: system user computer language human error us...  0.052192  0.055951
# 6: display technique study screen target intera...  0.083230  0.084911
# 15: mobile user phone feedback study base use l...  0.075524  0.074494
# 7: web user search information site page tool t...  0.045481  0.049391
# 19: interface design user application base syst...  0.028609  0.028975
# 11: design process note child new technology gr...  0.036882  0.041344
# 13: user menu application task time visual syst...  0.023867  0.027282
# 16: system communication video support collabor...  0.036793  0.030989
# 10: game video play online experience player ad...  0.033312  0.038338
# 8: device touch gesture input interaction hand ...  0.039139  0.038917
# 4: object physical interaction user computer in...  0.021981  0.024626
# 1: model eye pointing task device movement law ...  0.024838  0.019683
# 9: child interactive computer support study bli...  0.021341  0.023892
# 18: datum document information tag reader text ...  0.021020  0.021867
# 5: virtual focus space 3d interface environment...  0.019469  0.022570
# 3: voice usability user whisper labeling trace ...  0.015735  0.017681
# 0: user direct technique manipulation combinati...  0.014453  0.013217
# 12: audio recognition speech correction multimo...  0.012719  0.011488
#
#                                                         2013      2014
# 17: design social study technology paper resear...  0.300682  0.273909
# 14: user task result study participant performa...  0.106009  0.111505
# 2: system user computer language human error us...  0.049292  0.047576
# 6: display technique study screen target intera...  0.082791  0.083692
# 15: mobile user phone feedback study base use l...  0.069649  0.072908
# 7: web user search information site page tool t...  0.038121  0.041882
# 19: interface design user application base syst...  0.025763  0.025428
# 11: design process note child new technology gr...  0.042759  0.036550
# 13: user menu application task time visual syst...  0.027634  0.030389
# 16: system communication video support collabor...  0.026764  0.030098
# 10: game video play online experience player ad...  0.039376  0.046468
# 8: device touch gesture input interaction hand ...  0.043147  0.043931
# 4: object physical interaction user computer in...  0.023160  0.023590
# 1: model eye pointing task device movement law ...  0.022925  0.022395
# 9: child interactive computer support study bli...  0.017207  0.021011
# 18: datum document information tag reader text ...  0.018994  0.018577
# 5: virtual focus space 3d interface environment...  0.018278  0.020039
# 3: voice usability user whisper labeling trace ...  0.015308  0.019451
# 0: user direct technique manipulation combinati...  0.012808  0.012872
# 12: audio recognition speech correction multimo...  0.011337  0.010098
#
# [20 rows x 29 columns]

# %%
results.loc[results['Total'] > 0.05]
# Out:
#                                                        Total      1981  \
# 2: system user computer language human error us...  0.080703  0.179329
# 6: display technique study screen target intera...  0.079791  0.051794
# 7: web user search information site page tool t...  0.050218  0.076250
# 14: user task result study participant performa...  0.108849  0.086530
# 15: mobile user phone feedback study base use l...  0.058729  0.021700
# 17: design social study technology paper resear...  0.234840  0.236423
#
#                                                         1982      1983  \
# 2: system user computer language human error us...  0.251011  0.247499
# 6: display technique study screen target intera...  0.038180  0.073331
# 7: web user search information site page tool t...  0.037414  0.042798
# 14: user task result study participant performa...  0.116237  0.165163
# 15: mobile user phone feedback study base use l...  0.021576  0.011424
# 17: design social study technology paper resear...  0.177899  0.137802
#
#                                                         1985      1986  \
# 2: system user computer language human error us...  0.217451  0.220887
# 6: display technique study screen target intera...  0.069458  0.059668
# 7: web user search information site page tool t...  0.034620  0.044306
# 14: user task result study participant performa...  0.130173  0.122202
# 15: mobile user phone feedback study base use l...  0.021715  0.018696
# 17: design social study technology paper resear...  0.142281  0.135478
#
#                                                         1987      1988  \
# 2: system user computer language human error us...  0.129566  0.180947
# 6: display technique study screen target intera...  0.094265  0.074544
# 7: web user search information site page tool t...  0.042613  0.062445
# 14: user task result study participant performa...  0.152371  0.117824
# 15: mobile user phone feedback study base use l...  0.008166  0.013789
# 17: design social study technology paper resear...  0.187160  0.131294
#
#                                                         1989      1990  ...  \
# 2: system user computer language human error us...  0.161653  0.183297  ...
# 6: display technique study screen target intera...  0.055352  0.053479  ...
# 7: web user search information site page tool t...  0.039935  0.020804  ...
# 14: user task result study participant performa...  0.107342  0.071840  ...
# 15: mobile user phone feedback study base use l...  0.018828  0.016905  ...
# 17: design social study technology paper resear...  0.149790  0.197271  ...
#
#                                                         2005      2006  \
# 2: system user computer language human error us...  0.069058  0.066008
# 6: display technique study screen target intera...  0.097069  0.090238
# 7: web user search information site page tool t...  0.039305  0.062929
# 14: user task result study participant performa...  0.128787  0.116979
# 15: mobile user phone feedback study base use l...  0.067452  0.069420
# 17: design social study technology paper resear...  0.222582  0.199769
#
#                                                         2007      2008  \
# 2: system user computer language human error us...  0.065969  0.061561
# 6: display technique study screen target intera...  0.088269  0.095269
# 7: web user search information site page tool t...  0.053236  0.068440
# 14: user task result study participant performa...  0.126876  0.105741
# 15: mobile user phone feedback study base use l...  0.060991  0.069449
# 17: design social study technology paper resear...  0.218918  0.236515
#
#                                                         2009      2010  \
# 2: system user computer language human error us...  0.050566  0.061655
# 6: display technique study screen target intera...  0.084952  0.068186
# 7: web user search information site page tool t...  0.061760  0.050122
# 14: user task result study participant performa...  0.097439  0.116417
# 15: mobile user phone feedback study base use l...  0.071195  0.071161
# 17: design social study technology paper resear...  0.271270  0.270272
#
#                                                         2011      2012  \
# 2: system user computer language human error us...  0.052192  0.055951
# 6: display technique study screen target intera...  0.083230  0.084911
# 7: web user search information site page tool t...  0.045481  0.049391
# 14: user task result study participant performa...  0.107003  0.108926
# 15: mobile user phone feedback study base use l...  0.075524  0.074494
# 17: design social study technology paper resear...  0.278658  0.258245
#
#                                                         2013      2014
# 2: system user computer language human error us...  0.049292  0.047576
# 6: display technique study screen target intera...  0.082791  0.083692
# 7: web user search information site page tool t...  0.038121  0.041882
# 14: user task result study participant performa...  0.106009  0.111505
# 15: mobile user phone feedback study base use l...  0.069649  0.072908
# 17: design social study technology paper resear...  0.300682  0.273909
#
# [6 rows x 29 columns]

# %%
results[results['Total'] > 0.05].drop(columns=['Total']).T.plot.line( figsize=(15,10) )
