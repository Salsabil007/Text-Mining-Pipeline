# %% [markdown]
# ## 1 Set Up Environment
#
# We require the following packages and versions:
# * scikit-learn<0.24 (note that sklearn-crfsuite is incompatible with scikit-learn>=0.24)
# * sklearn-crfsuite==0.3.6 (https://github.com/TeamHG-Memex/sklearn-crfsuite)

# %%
# make sure the required python packages are installed

# install nltk (we'll use 3.6.7 in Spring 2022)
# !pip install nltk==3.6.7 --upgrade

# install spacy (we'll use 3.2.1 in Spring 2022)
# !pip install spacy==3.2.1 --upgrade

# upgrade scikit-learn 0.23.x (note that sklearn-crfsuite is inconsistent with scikit-learn>=0.24)
# !pip install 'scikit-learn>=0.23.0,<0.24.0' --upgrade

# upgrade scikit-learn 0.3.6
# !pip install 'sklearn-crfsuite==0.3.6' --upgrade

# download the spacy en_core_web_sm model (3.2.0 version)
# !python -m spacy download en_core_web_sm-3.2.0 --direct

# %%
conda install -c conda-forge sklearn-crfsuite
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/arabi/anaconda3
#
#   added / updated specs:
#     - sklearn-crfsuite
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     python-crfsuite-0.9.7      |   py38h2531618_1         181 KB
#     sklearn-crfsuite-0.3.6     |     pyh9f0ad1d_0          12 KB  conda-forge
#     tabulate-0.8.9             |     pyhd8ed1ab_0          26 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         219 KB
#
# The following NEW packages will be INSTALLED:
#
#   python-crfsuite    pkgs/main/linux-64::python-crfsuite-0.9.7-py38h2531618_1
#   sklearn-crfsuite   conda-forge/noarch::sklearn-crfsuite-0.3.6-pyh9f0ad1d_0
#   tabulate           conda-forge/noarch::tabulate-0.8.9-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages
# tabulate-0.8.9       | 26 KB     | ##################################### | 100%
# python-crfsuite-0.9. | 181 KB    | ##################################### | 100%
# sklearn-crfsuite-0.3 | 12 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.metrics import f1_score
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics

# %% [markdown]
# ## 2 Download the CoNLL2003 NER dataset and the Twitter NER dataset
#
# CoNLL2003 NER dataset:
# * training set: https://jiepujiang.github.io/data/CoNLL2003_ner_train.txt
# * test set: https://jiepujiang.github.io/data/CoNLL2003_ner_test.txt
#
# Twitter NER dataset:
# * whole dataset: https://jiepujiang.github.io/data/twitter_ner.txt

# %%
# A utility function for reading the dataset (from the web).
# Only load the first (word) and last columns (IOB label).

import re
import requests

# regularize the name for person and geo-loc tags on different datasets
def transform_label(old):
    if old=='B-PER' or old=='B-person':
        return 'B-PER'
    if old=='I-PER' or old=='I-person':
        return 'I-PER'
    if old=='B-LOC' or old=='B-geo-loc':
        return 'B-LOC'
    if old=='I-LOC' or old=='I-geo-loc':
        return 'I-LOC'
    return old
def transform_human(old):
    for i in range(len(old)):
        for j in range(len(old[i])):
            if old[i][j] != 'B-PER' and old[i][j] != 'I-PER':
                old[i][j] = 'O'
    return old
def load_dataset(url):
    sents = []
    response = requests.get(url)
    sent = []
    for line in response.iter_lines(decode_unicode=True):
        line = line.strip()
        if len(line)==0 or line[0:10]=='-DOCSTART-':
            if len(sent)>0:
                sents.append(sent)
                sent = []
        else:
            tokens = re.split('\\s+', line)
            sent.append([tokens[0], transform_label(tokens[-1])])
    return sents
def ext_occurrence(list_labels, type):
    left,right = -1,-1
    lim = []
    for i in range(len(list_labels)):
        if list_labels[i]=='B-'+type: #beginning of new entity
            if left>=0 and right>=0: #save the previous one if existed
                lim.append((left, right))
            left, right = i,i
        elif list_labels[i]=='I-'+type: #onging entity: forward the right edge
            right = i
        else: ##anything else: end of an entity or continued "O"
            if left>=0 and right>=0:
                lim.append((left, right))
                left,right = -1,-1
    if left>=0 and right>=0:
        lim.append((left, right))
    return lim

def eval(Y, Y_pred, type):
    total_y = 0
    total_y_pred = 0
    correct = 0
    for (y, y_pred) in zip(Y, Y_pred):
        oc_y = ext_occurrence(y, type)
        oc_y_pred = ext_occurrence(y_pred, type)
        total_y += len(oc_y)
        total_y_pred += len(oc_y_pred)
        correct += len([ oc for oc in oc_y if oc in oc_y_pred ])
    return {
        'F1(%s)' % type: 0.0 if correct==0 else float("{0:.3f}".format(2.0*correct/(total_y+total_y_pred))),
        'Pre(%s)' % type: 0.0 if correct==0 else float("{0:.3f}".format(correct/total_y_pred)),
        'Rec(%s)' % type: 0.0 if correct==0 else float("{0:.3f}".format(correct/total_y)),
        
    }

# %%
# load the dataset files

url_conll2003_train = 'https://jiepujiang.github.io/data/CoNLL2003_ner_train.txt'
url_conll2003_test = 'https://jiepujiang.github.io/data/CoNLL2003_ner_test.txt'
url_twitter_ner = 'https://jiepujiang.github.io/data/twitter_ner.txt'

conll2003_train = load_dataset(url_conll2003_train)
conll2003_test = load_dataset(url_conll2003_test)
twitter_ner = load_dataset(url_twitter_ner)

print( len(conll2003_train), len(conll2003_test), len(twitter_ner) )
# Out:
# 14401 3546 2467

# %%
# sentence[4] in conll2003_train

conll2003_train[4]
# Out:
# [['Germany', 'B-LOC'],
#  ["'s", 'O'],
#  ['representative', 'O'],
#  ['to', 'O'],
#  ['the', 'O'],
#  ['European', 'B-ORG'],
#  ['Union', 'I-ORG'],
#  ["'s", 'O'],
#  ['veterinary', 'O'],
#  ['committee', 'O'],
#  ['Werner', 'B-PER'],
#  ['Zwingmann', 'I-PER'],
#  ['said', 'O'],
#  ['on', 'O'],
#  ['Wednesday', 'O'],
#  ['consumers', 'O'],
#  ['should', 'O'],
#  ['buy', 'O'],
#  ['sheepmeat', 'O'],
#  ['from', 'O'],
#  ['countries', 'O'],
#  ['other', 'O'],
#  ['than', 'O'],
#  ['Britain', 'B-LOC'],
#  ['until', 'O'],
#  ['the', 'O'],
#  ['scientific', 'O'],
#  ['advice', 'O'],
#  ['was', 'O'],
#  ['clearer', 'O'],
#  ['.', 'O']]

# %%
# sentence[4]'s first token in conll2003_train is 'Germany' and its IOB-style tag is 'B-LOC'
conll2003_train[4][0]
# Out:
# ['Germany', 'B-LOC']

# %%
import re

# w[offset]=? for the ith word in a sentence
# e.g., w[0] = current word
#       w[-1] = the previous word
#       w[1] = the next word
#       w[2], w[-2], w[3], w[-3]
def feat_w(sent, i, offset):
    if i+offset<0:
        return { 'w[%d]' % offset : '<S>' }
    if i+offset>=len(sent):
        return { 'w[%d]' % offset : '</S>' }
    else:
        return { 'w[%d]' % offset : sent[i+offset][0] }
    
def feat_w_casefold(sent, i, offset):
    if i+offset<0:
        return { 'w[%d]' % offset : '<S>' }
    if i+offset>=len(sent):
        return { 'w[%d]' % offset : '</S>' }
    else:
        return { 'w[%d].lower()' % offset : sent[i+offset][0].lower() }

# whether the word is alphanumeric (consisting of both letters and digits)
def feat_alphanumeric(sent, i):
    val = re.fullmatch('[a-zA-Z0-9]+', sent[i][0])!=None and re.fullmatch('[a-zA-Z]+', sent[i][0])==None and re.fullmatch('[0-9]+', sent[i][0])==None
    return { 'alphanumeric': val }

# whether the word has a dash
def feat_hasdash(sent, i):
    return { 'hasdash': ( '-' in sent[i][0] ) }

# prefix of length $len
def feat_prefix(sent, i, len):
    return { 'prefix[len=%d]' % len: sent[i][0][:len] }

def feat_prefix_casefold(sent, i, len):
    return { 'prefix[len=%d].lower()' % len: sent[i][0][:len].lower() }



# suffix of length $len
def feat_suffix(sent, i, len):
    return { 'suffix[len=%d]' % len: sent[i][0][-len:] }

def feat_suffix_casefold(sent, i, len):
    return { 'suffix[len=%d].lower()' % len: sent[i][0][-len:].lower() }

# character k-gram for the ith word in a sentence
def feat_charngram(sent, i, k):
    return { 'char-%dgram=%s' % (k,sent[i][0][j:j+k]):True for j in range(len(sent[i][0])-k+1) }

# a simple word shape feature: uppercase letter-->X, lowercase-->x, digit-->d
def feat_wordshape(sent, i):
    shape = re.sub('[A-Z]', 'X', sent[i][0])
    shape = re.sub('[a-z]', 'x', shape)
    shape = re.sub('[0-9]', 'd', shape)
    return { 'shape':shape }

# a shorter word shape feature that collapses consecutive identical characters into one
def feat_wordshape_short(sent, i):
    shape = feat_wordshape(sent, i)['shape'];
    shape = re.sub('X+', 'X', shape)
    shape = re.sub('x+', 'x', shape)
    shape = re.sub('d+', 'd', shape)
    return { 'shapeshort':shape }

# %%
def feat_sent(sent,allfet,word,presuf,shp,case_fold):
    
    sent_feats = []

    for i in range(len(sent)):

        feats = {}
        
        if (allfet == 1 and case_fold == 0):
            # word features
            feats.update( feat_w(sent, i, 0) )
            feats.update( feat_w(sent, i, 1) )
            feats.update( feat_w(sent, i, -1) )

            # prefix and suffix
            feats.update( feat_prefix(sent, i, 3) )
            feats.update( feat_prefix(sent, i, 4) )
            feats.update( feat_prefix(sent, i, 5) )
            feats.update( feat_suffix(sent, i, 3) )
            feats.update( feat_suffix(sent, i, 4) )
            feats.update( feat_suffix(sent, i, 5) )


            # word shape
            feats.update( feat_alphanumeric(sent, i) )
            feats.update( feat_hasdash(sent, i) )
            feats.update( feat_wordshape(sent, i) )
            feats.update( feat_wordshape_short(sent, i) )
            
        elif (allfet == 1 and case_fold == 1):
            #print("yes!")
            # word features
            feats.update( feat_w(sent, i, 0) )
            feats.update( feat_w(sent, i, 1) )
            feats.update( feat_w(sent, i, -1) )
            feats.update( feat_w_casefold(sent, i, 0) )
            feats.update( feat_w_casefold(sent, i, 1) )
            feats.update( feat_w_casefold(sent, i, -1) )

            # prefix and suffix
            feats.update( feat_prefix(sent, i, 3) )
            feats.update( feat_prefix(sent, i, 4) )
            feats.update( feat_prefix(sent, i, 5) )
            feats.update( feat_suffix(sent, i, 3) )
            feats.update( feat_suffix(sent, i, 4) )
            feats.update( feat_suffix(sent, i, 5) )
            feats.update( feat_prefix_casefold(sent, i, 3))
            feats.update( feat_prefix_casefold(sent, i, 4))
            feats.update( feat_prefix_casefold(sent, i, 5))
            feats.update( feat_suffix_casefold(sent, i, 3) )
            feats.update( feat_suffix_casefold(sent, i, 4) )
            feats.update( feat_suffix_casefold(sent, i, 5))


            # word shape
            feats.update( feat_alphanumeric(sent, i) )
            feats.update( feat_hasdash(sent, i) )
            feats.update( feat_wordshape(sent, i) )
            feats.update( feat_wordshape_short(sent, i) )
        
        elif (allfet == 0 and word == 1):
            feats.update( feat_w(sent, i, 0) )
            feats.update( feat_w(sent, i, 1) )
            feats.update( feat_w(sent, i, -1) )
            
            if case_fold == 1:
                feats.update( feat_w_casefold(sent, i, 0))
                feats.update( feat_w_casefold(sent, i, 1) )
                feats.update( feat_w_casefold(sent, i, -1) )
                
        elif (allfet == 0 and presuf == 1):
            feats.update( feat_prefix(sent, i, 3) )
            feats.update( feat_prefix(sent, i, 4) )
            feats.update( feat_prefix(sent, i, 5) )
            feats.update( feat_suffix(sent, i, 3) )
            feats.update( feat_suffix(sent, i, 4) )
            feats.update( feat_suffix(sent, i, 5) )
            
            if case_fold == 1:
                feats.update( feat_prefix_casefold(sent, i, 3))
                feats.update( feat_prefix_casefold(sent, i, 4))
                feats.update( feat_prefix_casefold(sent, i, 5))
                feats.update( feat_suffix_casefold(sent, i, 3) )
                feats.update( feat_suffix_casefold(sent, i, 4) )
                feats.update( feat_suffix_casefold(sent, i, 5))
                
        elif (allfet == 0 and shp == 1):
            feats.update( feat_alphanumeric(sent, i) )
            feats.update( feat_hasdash(sent, i) )
            feats.update( feat_wordshape(sent, i) )
            feats.update( feat_wordshape_short(sent, i) )
            
        else:
            if case_fold == 0:
                if word == -1:
                    
                    feats.update( feat_prefix(sent, i, 3) )
                    feats.update( feat_prefix(sent, i, 4) )
                    feats.update( feat_prefix(sent, i, 5) )
                    feats.update( feat_suffix(sent, i, 3) )
                    feats.update( feat_suffix(sent, i, 4) )
                    feats.update( feat_suffix(sent, i, 5) )


                    # word shape
                    feats.update( feat_alphanumeric(sent, i) )
                    feats.update( feat_hasdash(sent, i) )
                    feats.update( feat_wordshape(sent, i) )
                    feats.update( feat_wordshape_short(sent, i) )
                    
                elif presuf == -1:
                    feats.update( feat_w(sent, i, 0) )
                    feats.update( feat_w(sent, i, 1) )
                    feats.update( feat_w(sent, i, -1) )


                    # word shape
                    feats.update( feat_alphanumeric(sent, i) )
                    feats.update( feat_hasdash(sent, i) )
                    feats.update( feat_wordshape(sent, i) )
                    feats.update( feat_wordshape_short(sent, i) )
                    
                elif shp == -1:
                    feats.update( feat_w(sent, i, 0) )
                    feats.update( feat_w(sent, i, 1) )
                    feats.update( feat_w(sent, i, -1) )

                    # prefix and suffix
                    feats.update( feat_prefix(sent, i, 3) )
                    feats.update( feat_prefix(sent, i, 4) )
                    feats.update( feat_prefix(sent, i, 5) )
                    feats.update( feat_suffix(sent, i, 3) )
                    feats.update( feat_suffix(sent, i, 4) )
                    feats.update( feat_suffix(sent, i, 5) )
                    
            elif case_fold == 1:
                if word == -1:
                    feats.update( feat_prefix(sent, i, 3) )
                    feats.update( feat_prefix(sent, i, 4) )
                    feats.update( feat_prefix(sent, i, 5) )
                    feats.update( feat_suffix(sent, i, 3) )
                    feats.update( feat_suffix(sent, i, 4) )
                    feats.update( feat_suffix(sent, i, 5) )
                    feats.update( feat_prefix_casefold(sent, i, 3))
                    feats.update( feat_prefix_casefold(sent, i, 4))
                    feats.update( feat_prefix_casefold(sent, i, 5))
                    feats.update( feat_suffix_casefold(sent, i, 3) )
                    feats.update( feat_suffix_casefold(sent, i, 4) )
                    feats.update( feat_suffix_casefold(sent, i, 5))

                    # word shape
                    feats.update( feat_alphanumeric(sent, i) )
                    feats.update( feat_hasdash(sent, i) )
                    feats.update( feat_wordshape(sent, i) )
                    feats.update( feat_wordshape_short(sent, i) )
                    
                elif presuf == -1:
                    feats.update( feat_w(sent, i, 0) )
                    feats.update( feat_w(sent, i, 1) )
                    feats.update( feat_w(sent, i, -1) )
                    feats.update( feat_w_casefold(sent, i, 0))
                    feats.update( feat_w_casefold(sent, i, 1) )
                    feats.update( feat_w_casefold(sent, i, -1) )

                    # word shape
                    feats.update( feat_alphanumeric(sent, i) )
                    feats.update( feat_hasdash(sent, i) )
                    feats.update( feat_wordshape(sent, i) )
                    feats.update( feat_wordshape_short(sent, i) )
                    
                elif shp == -1:
                    feats.update( feat_w(sent, i, 0) )
                    feats.update( feat_w(sent, i, 1) )
                    feats.update( feat_w(sent, i, -1) )
                    feats.update( feat_w_casefold(sent, i, 0))
                    feats.update( feat_w_casefold(sent, i, 1) )
                    feats.update( feat_w_casefold(sent, i, -1) )

                    # prefix and suffix
                    feats.update( feat_prefix(sent, i, 3) )
                    feats.update( feat_prefix(sent, i, 4) )
                    feats.update( feat_prefix(sent, i, 5) )
                    feats.update( feat_suffix(sent, i, 3) )
                    feats.update( feat_suffix(sent, i, 4) )
                    feats.update( feat_suffix(sent, i, 5) )
                    
                    
            
            

        sent_feats.append(feats)

    return sent_feats

# %%
def label_sent(sent):
    return [ token[1] for token in sent ]

# %%
'''import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics

def performmm(ctrain_X,ctrain_Y,ctest_X,ctest_Y):
    crf = sklearn_crfsuite.CRF(
        algorithm='lbfgs', # default; Gradient descent using the L-BFGS method
        min_freq=5, # the minimum freq of a feature in the training set
        max_iterations=100, # set this value to stop the training after k epochs
    )

    # train a CRF model on the training set
    try:
        crf.fit(ctrain_X, ctrain_Y)
    except AttributeError:
        pass
    cY_pred = crf.predict(ctest_X)
    cY_pred = transform_label(cY_pred)
    ctest_Y = transform_label(ctest_Y)
    eval(ctest_Y, cY_pred, "LOC")'''
# Out:
# 'import sklearn_crfsuite\nfrom sklearn_crfsuite import scorers\nfrom sklearn_crfsuite import metrics\n\ndef performmm(ctrain_X,ctrain_Y,ctest_X,ctest_Y):\n    crf = sklearn_crfsuite.CRF(\n        algorithm=\'lbfgs\', # default; Gradient descent using the L-BFGS method\n        min_freq=5, # the minimum freq of a feature in the training set\n        max_iterations=100, # set this value to stop the training after k epochs\n    )\n\n    # train a CRF model on the training set\n    try:\n        crf.fit(ctrain_X, ctrain_Y)\n    except AttributeError:\n        pass\n    cY_pred = crf.predict(ctest_X)\n    cY_pred = transform_label(cY_pred)\n    ctest_Y = transform_label(ctest_Y)\n    eval(ctest_Y, cY_pred, "LOC")'

# %%
print("Table 1")
#table_1 row_1
ctrain_X = [ feat_sent(sent,1,0,0,0,0) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
ctest_X = [ feat_sent(sent,1,0,0,0,0) for sent in conll2003_test ]
ctest_Y = [ label_sent(sent) for sent in conll2003_test ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)

#table_1 row_2
ctrain_X = [ feat_sent(sent,0,-1,0,0,0) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
ctest_X = [ feat_sent(sent,0,-1,0,0,0) for sent in conll2003_test ]
ctest_Y = [ label_sent(sent) for sent in conll2003_test ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)

#table_1 row_3
ctrain_X = [ feat_sent(sent,0,0,-1,0,0) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
#ctrain_Y = transform_label(ctrain_Y)
ctest_X = [ feat_sent(sent,0,0,-1,0,0) for sent in conll2003_test ]
ctest_Y = [ label_sent(sent) for sent in conll2003_test ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)

#table_1 row_4
ctrain_X = [ feat_sent(sent,0,0,0,-1,0) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
#ctrain_Y = transform_label(ctrain_Y)
ctest_X = [ feat_sent(sent,0,0,0,-1,0) for sent in conll2003_test ]
ctest_Y = [ label_sent(sent) for sent in conll2003_test ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)

#table_1 row_5
ctrain_X = [ feat_sent(sent,0,1,0,0,0) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
#ctrain_Y = transform_label(ctrain_Y)
ctest_X = [ feat_sent(sent,0,1,0,0,0) for sent in conll2003_test ]
ctest_Y = [ label_sent(sent) for sent in conll2003_test ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)

#table_1 row_6
ctrain_X = [ feat_sent(sent,0,0,1,0,0) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
#ctrain_Y = transform_label(ctrain_Y)
ctest_X = [ feat_sent(sent,0,0,1,0,0) for sent in conll2003_test ]
ctest_Y = [ label_sent(sent) for sent in conll2003_test ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)

#table_1 row_7
ctrain_X = [ feat_sent(sent,0,0,0,1,0) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
#ctrain_Y = transform_label(ctrain_Y)
ctest_X = [ feat_sent(sent,0,0,0,1,0) for sent in conll2003_test ]
ctest_Y = [ label_sent(sent) for sent in conll2003_test ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)



print("Table 2")
#table_1 row_1
ctrain_X = [ feat_sent(sent,1,0,0,0,1) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
ctest_X = [ feat_sent(sent,1,0,0,0,1) for sent in conll2003_test ]
ctest_Y = [ label_sent(sent) for sent in conll2003_test ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)

#table_1 row_2
ctrain_X = [ feat_sent(sent,0,-1,0,0,1) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
ctest_X = [ feat_sent(sent,0,-1,0,0,1) for sent in conll2003_test ]
ctest_Y = [ label_sent(sent) for sent in conll2003_test ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)

#table_1 row_3
ctrain_X = [ feat_sent(sent,0,0,-1,0,1) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
#ctrain_Y = transform_label(ctrain_Y)
ctest_X = [ feat_sent(sent,0,0,-1,0,1) for sent in conll2003_test ]
ctest_Y = [ label_sent(sent) for sent in conll2003_test ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)

#table_1 row_4
ctrain_X = [ feat_sent(sent,0,0,0,-1,1) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
#ctrain_Y = transform_label(ctrain_Y)
ctest_X = [ feat_sent(sent,0,0,0,-1,1) for sent in conll2003_test ]
ctest_Y = [ label_sent(sent) for sent in conll2003_test ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)

#table_1 row_5
ctrain_X = [ feat_sent(sent,0,1,0,0,1) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
#ctrain_Y = transform_label(ctrain_Y)
ctest_X = [ feat_sent(sent,0,1,0,0,1) for sent in conll2003_test ]
ctest_Y = [ label_sent(sent) for sent in conll2003_test ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)

#table_1 row_6
ctrain_X = [ feat_sent(sent,0,0,1,0,1) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
#ctrain_Y = transform_label(ctrain_Y)
ctest_X = [ feat_sent(sent,0,0,1,0,1) for sent in conll2003_test ]
ctest_Y = [ label_sent(sent) for sent in conll2003_test ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)

#table_1 row_7
ctrain_X = [ feat_sent(sent,0,0,0,1,1) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
#ctrain_Y = transform_label(ctrain_Y)
ctest_X = [ feat_sent(sent,0,0,0,1,1) for sent in conll2003_test ]
ctest_Y = [ label_sent(sent) for sent in conll2003_test ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)



print("table 3")
#table_3 row_1
ctrain_X = [ feat_sent(sent,1,0,0,0,0) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
ctest_X = [ feat_sent(sent,1,0,0,0,0) for sent in twitter_ner ]
ctest_Y = [ label_sent(sent) for sent in twitter_ner ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)

#table_3 row_2
ctrain_X = [ feat_sent(sent,0,-1,0,0,0) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
ctest_X = [ feat_sent(sent,0,-1,0,0,0) for sent in twitter_ner ]
ctest_Y = [ label_sent(sent) for sent in twitter_ner ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)

#table_3 row_3
ctrain_X = [ feat_sent(sent,0,0,-1,0,0) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
#ctrain_Y = transform_label(ctrain_Y)
ctest_X = [ feat_sent(sent,0,0,-1,0,0) for sent in twitter_ner ]
ctest_Y = [ label_sent(sent) for sent in twitter_ner ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)

#table_3 row_4
ctrain_X = [ feat_sent(sent,0,0,0,-1,0) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
#ctrain_Y = transform_label(ctrain_Y)
ctest_X = [ feat_sent(sent,0,0,0,-1,0) for sent in twitter_ner ]
ctest_Y = [ label_sent(sent) for sent in twitter_ner ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)

#table_3 row_5
ctrain_X = [ feat_sent(sent,0,1,0,0,0) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
#ctrain_Y = transform_label(ctrain_Y)
ctest_X = [ feat_sent(sent,0,1,0,0,0) for sent in twitter_ner]
ctest_Y = [ label_sent(sent) for sent in twitter_ner ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)

#table_3 row_6
ctrain_X = [ feat_sent(sent,0,0,1,0,0) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
#ctrain_Y = transform_label(ctrain_Y)
ctest_X = [ feat_sent(sent,0,0,1,0,0) for sent in twitter_ner ]
ctest_Y = [ label_sent(sent) for sent in twitter_ner ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)

#table_3 row_7
ctrain_X = [ feat_sent(sent,0,0,0,1,0) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
#ctrain_Y = transform_label(ctrain_Y)
ctest_X = [ feat_sent(sent,0,0,0,1,0) for sent in twitter_ner ]
ctest_Y = [ label_sent(sent) for sent in twitter_ner ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)

print("table 4")
#table_3 row_1
ctrain_X = [ feat_sent(sent,1,0,0,0,1) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
ctest_X = [ feat_sent(sent,1,0,0,0,1) for sent in twitter_ner ]
ctest_Y = [ label_sent(sent) for sent in twitter_ner ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)

#table_3 row_2
ctrain_X = [ feat_sent(sent,0,-1,0,0,1) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
ctest_X = [ feat_sent(sent,0,-1,0,0,1) for sent in twitter_ner ]
ctest_Y = [ label_sent(sent) for sent in twitter_ner ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)

#table_3 row_3
ctrain_X = [ feat_sent(sent,0,0,-1,0,1) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
#ctrain_Y = transform_label(ctrain_Y)
ctest_X = [ feat_sent(sent,0,0,-1,0,1) for sent in twitter_ner ]
ctest_Y = [ label_sent(sent) for sent in twitter_ner ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)

#table_3 row_4
ctrain_X = [ feat_sent(sent,0,0,0,-1,1) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
#ctrain_Y = transform_label(ctrain_Y)
ctest_X = [ feat_sent(sent,0,0,0,-1,1) for sent in twitter_ner ]
ctest_Y = [ label_sent(sent) for sent in twitter_ner ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)

#table_3 row_5
ctrain_X = [ feat_sent(sent,0,1,0,0,1) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
#ctrain_Y = transform_label(ctrain_Y)
ctest_X = [ feat_sent(sent,0,1,0,0,1) for sent in twitter_ner]
ctest_Y = [ label_sent(sent) for sent in twitter_ner ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)

#table_3 row_6
ctrain_X = [ feat_sent(sent,0,0,1,0,1) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
#ctrain_Y = transform_label(ctrain_Y)
ctest_X = [ feat_sent(sent,0,0,1,0,1) for sent in twitter_ner ]
ctest_Y = [ label_sent(sent) for sent in twitter_ner ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)

#table_3 row_7
ctrain_X = [ feat_sent(sent,0,0,0,1,1) for sent in conll2003_train ]
ctrain_Y = [ label_sent(sent) for sent in conll2003_train ]
#ctrain_Y = transform_label(ctrain_Y)
ctest_X = [ feat_sent(sent,0,0,0,1,1) for sent in twitter_ner ]
ctest_Y = [ label_sent(sent) for sent in twitter_ner ]
perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y)

#ttest_X = [ feat_sent(sent,1,0,0,0,0) for sent in twitter_ner ]
#ttest_Y = [ label_sent(sent) for sent in twitter_ner ]
#ttest_Y = transform_label(ttest_Y)
# Out:
# Table 1
# {'F1(LOC)': 0.832, 'Pre(LOC)': 0.856, 'Rec(LOC)': 0.81} {'F1(PER)': 0.851, 'Pre(PER)': 0.832, 'Rec(PER)': 0.871}
# {'F1(LOC)': 0.79, 'Pre(LOC)': 0.801, 'Rec(LOC)': 0.779} {'F1(PER)': 0.786, 'Pre(PER)': 0.777, 'Rec(PER)': 0.795}
# {'F1(LOC)': 0.782, 'Pre(LOC)': 0.827, 'Rec(LOC)': 0.742} {'F1(PER)': 0.805, 'Pre(PER)': 0.779, 'Rec(PER)': 0.832}
# {'F1(LOC)': 0.801, 'Pre(LOC)': 0.88, 'Rec(LOC)': 0.736} {'F1(PER)': 0.776, 'Pre(PER)': 0.836, 'Rec(PER)': 0.724}
# {'F1(LOC)': 0.703, 'Pre(LOC)': 0.931, 'Rec(LOC)': 0.565} {'F1(PER)': 0.657, 'Pre(PER)': 0.817, 'Rec(PER)': 0.549}
# {'F1(LOC)': 0.775, 'Pre(LOC)': 0.847, 'Rec(LOC)': 0.715} {'F1(PER)': 0.675, 'Pre(PER)': 0.716, 'Rec(PER)': 0.639}
# {'F1(LOC)': 0.427, 'Pre(LOC)': 0.387, 'Rec(LOC)': 0.477} {'F1(PER)': 0.561, 'Pre(PER)': 0.568, 'Rec(PER)': 0.555}
# Table 2
# {'F1(LOC)': 0.843, 'Pre(LOC)': 0.848, 'Rec(LOC)': 0.839} {'F1(PER)': 0.853, 'Pre(PER)': 0.836, 'Rec(PER)': 0.871}
# {'F1(LOC)': 0.811, 'Pre(LOC)': 0.814, 'Rec(LOC)': 0.808} {'F1(PER)': 0.786, 'Pre(PER)': 0.784, 'Rec(PER)': 0.788}
# {'F1(LOC)': 0.813, 'Pre(LOC)': 0.851, 'Rec(LOC)': 0.778} {'F1(PER)': 0.817, 'Pre(PER)': 0.793, 'Rec(PER)': 0.844}
# {'F1(LOC)': 0.81, 'Pre(LOC)': 0.887, 'Rec(LOC)': 0.745} {'F1(PER)': 0.778, 'Pre(PER)': 0.825, 'Rec(PER)': 0.735}
# {'F1(LOC)': 0.756, 'Pre(LOC)': 0.908, 'Rec(LOC)': 0.648} {'F1(PER)': 0.652, 'Pre(PER)': 0.788, 'Rec(PER)': 0.556}
# {'F1(LOC)': 0.788, 'Pre(LOC)': 0.818, 'Rec(LOC)': 0.76} {'F1(PER)': 0.697, 'Pre(PER)': 0.754, 'Rec(PER)': 0.648}
# {'F1(LOC)': 0.427, 'Pre(LOC)': 0.387, 'Rec(LOC)': 0.477} {'F1(PER)': 0.561, 'Pre(PER)': 0.568, 'Rec(PER)': 0.555}
# table 3
# {'F1(LOC)': 0.423, 'Pre(LOC)': 0.412, 'Rec(LOC)': 0.435} {'F1(PER)': 0.378, 'Pre(PER)': 0.298, 'Rec(PER)': 0.517}
# {'F1(LOC)': 0.235, 'Pre(LOC)': 0.235, 'Rec(LOC)': 0.236} {'F1(PER)': 0.237, 'Pre(PER)': 0.156, 'Rec(PER)': 0.497}
# {'F1(LOC)': 0.407, 'Pre(LOC)': 0.398, 'Rec(LOC)': 0.417} {'F1(PER)': 0.339, 'Pre(PER)': 0.281, 'Rec(PER)': 0.428}
# {'F1(LOC)': 0.39, 'Pre(LOC)': 0.512, 'Rec(LOC)': 0.315} {'F1(PER)': 0.352, 'Pre(PER)': 0.322, 'Rec(PER)': 0.388}
# {'F1(LOC)': 0.234, 'Pre(LOC)': 0.547, 'Rec(LOC)': 0.149} {'F1(PER)': 0.17, 'Pre(PER)': 0.287, 'Rec(PER)': 0.12}
# {'F1(LOC)': 0.264, 'Pre(LOC)': 0.378, 'Rec(LOC)': 0.203} {'F1(PER)': 0.161, 'Pre(PER)': 0.1, 'Rec(PER)': 0.416}
# {'F1(LOC)': 0.139, 'Pre(LOC)': 0.095, 'Rec(LOC)': 0.257} {'F1(PER)': 0.153, 'Pre(PER)': 0.115, 'Rec(PER)': 0.227}
# table 4
# {'F1(LOC)': 0.421, 'Pre(LOC)': 0.396, 'Rec(LOC)': 0.449} {'F1(PER)': 0.377, 'Pre(PER)': 0.296, 'Rec(PER)': 0.521}
# {'F1(LOC)': 0.264, 'Pre(LOC)': 0.263, 'Rec(LOC)': 0.264} {'F1(PER)': 0.242, 'Pre(PER)': 0.16, 'Rec(PER)': 0.501}
# {'F1(LOC)': 0.426, 'Pre(LOC)': 0.414, 'Rec(LOC)': 0.438} {'F1(PER)': 0.36, 'Pre(PER)': 0.302, 'Rec(PER)': 0.445}
# {'F1(LOC)': 0.412, 'Pre(LOC)': 0.538, 'Rec(LOC)': 0.333} {'F1(PER)': 0.366, 'Pre(PER)': 0.346, 'Rec(PER)': 0.388}
# {'F1(LOC)': 0.306, 'Pre(LOC)': 0.541, 'Rec(LOC)': 0.214} {'F1(PER)': 0.189, 'Pre(PER)': 0.281, 'Rec(PER)': 0.143}
# {'F1(LOC)': 0.308, 'Pre(LOC)': 0.391, 'Rec(LOC)': 0.254} {'F1(PER)': 0.195, 'Pre(PER)': 0.123, 'Rec(PER)': 0.472}
# {'F1(LOC)': 0.139, 'Pre(LOC)': 0.095, 'Rec(LOC)': 0.257} {'F1(PER)': 0.153, 'Pre(PER)': 0.115, 'Rec(PER)': 0.227}

# %%
ctrain_X[0]
# Out:
# [{'w[0]': 'EU',
#   'w[1]': 'rejects',
#   'w[-1]': '<S>',
#   'w[0].lower()': 'eu',
#   'w[1].lower()': 'rejects',
#   'prefix[len=3]': 'EU',
#   'prefix[len=4]': 'EU',
#   'prefix[len=5]': 'EU',
#   'suffix[len=3]': 'EU',
#   'suffix[len=4]': 'EU',
#   'suffix[len=5]': 'EU',
#   'prefix[len=3].lower()': 'eu',
#   'prefix[len=4].lower()': 'eu',
#   'prefix[len=5].lower()': 'eu',
#   'suffix[len=3].lower()': 'eu',
#   'suffix[len=4].lower()': 'eu',
#   'suffix[len=5].lower()': 'eu',
#   'alphanumeric': False,
#   'hasdash': False,
#   'shape': 'XX',
#   'shapeshort': 'X'},
#  {'w[0]': 'rejects',
#   'w[1]': 'German',
#   'w[-1]': 'EU',
#   'w[0].lower()': 'rejects',
#   'w[1].lower()': 'german',
#   'w[-1].lower()': 'eu',
#   'prefix[len=3]': 'rej',
#   'prefix[len=4]': 'reje',
#   'prefix[len=5]': 'rejec',
#   'suffix[len=3]': 'cts',
#   'suffix[len=4]': 'ects',
#   'suffix[len=5]': 'jects',
#   'prefix[len=3].lower()': 'rej',
#   'prefix[len=4].lower()': 'reje',
#   'prefix[len=5].lower()': 'rejec',
#   'suffix[len=3].lower()': 'cts',
#   'suffix[len=4].lower()': 'ects',
#   'suffix[len=5].lower()': 'jects',
#   'alphanumeric': False,
#   'hasdash': False,
#   'shape': 'xxxxxxx',
#   'shapeshort': 'x'},
#  {'w[0]': 'German',
#   'w[1]': 'call',
#   'w[-1]': 'rejects',
#   'w[0].lower()': 'german',
#   'w[1].lower()': 'call',
#   'w[-1].lower()': 'rejects',
#   'prefix[len=3]': 'Ger',
#   'prefix[len=4]': 'Germ',
#   'prefix[len=5]': 'Germa',
#   'suffix[len=3]': 'man',
#   'suffix[len=4]': 'rman',
#   'suffix[len=5]': 'erman',
#   'prefix[len=3].lower()': 'ger',
#   'prefix[len=4].lower()': 'germ',
#   'prefix[len=5].lower()': 'germa',
#   'suffix[len=3].lower()': 'man',
#   'suffix[len=4].lower()': 'rman',
#   'suffix[len=5].lower()': 'erman',
#   'alphanumeric': False,
#   'hasdash': False,
#   'shape': 'Xxxxxx',
#   'shapeshort': 'Xx'},
#  {'w[0]': 'call',
#   'w[1]': 'to',
#   'w[-1]': 'German',
#   'w[0].lower()': 'call',
#   'w[1].lower()': 'to',
#   'w[-1].lower()': 'german',
#   'prefix[len=3]': 'cal',
#   'prefix[len=4]': 'call',
#   'prefix[len=5]': 'call',
#   'suffix[len=3]': 'all',
#   'suffix[len=4]': 'call',
#   'suffix[len=5]': 'call',
#   'prefix[len=3].lower()': 'cal',
#   'prefix[len=4].lower()': 'call',
#   'prefix[len=5].lower()': 'call',
#   'suffix[len=3].lower()': 'all',
#   'suffix[len=4].lower()': 'call',
#   'suffix[len=5].lower()': 'call',
#   'alphanumeric': False,
#   'hasdash': False,
#   'shape': 'xxxx',
#   'shapeshort': 'x'},
#  {'w[0]': 'to',
#   'w[1]': 'boycott',
#   'w[-1]': 'call',
#   'w[0].lower()': 'to',
#   'w[1].lower()': 'boycott',
#   'w[-1].lower()': 'call',
#   'prefix[len=3]': 'to',
#   'prefix[len=4]': 'to',
#   'prefix[len=5]': 'to',
#   'suffix[len=3]': 'to',
#   'suffix[len=4]': 'to',
#   'suffix[len=5]': 'to',
#   'prefix[len=3].lower()': 'to',
#   'prefix[len=4].lower()': 'to',
#   'prefix[len=5].lower()': 'to',
#   'suffix[len=3].lower()': 'to',
#   'suffix[len=4].lower()': 'to',
#   'suffix[len=5].lower()': 'to',
#   'alphanumeric': False,
#   'hasdash': False,
#   'shape': 'xx',
#   'shapeshort': 'x'},
#  {'w[0]': 'boycott',
#   'w[1]': 'British',
#   'w[-1]': 'to',
#   'w[0].lower()': 'boycott',
#   'w[1].lower()': 'british',
#   'w[-1].lower()': 'to',
#   'prefix[len=3]': 'boy',
#   'prefix[len=4]': 'boyc',
#   'prefix[len=5]': 'boyco',
#   'suffix[len=3]': 'ott',
#   'suffix[len=4]': 'cott',
#   'suffix[len=5]': 'ycott',
#   'prefix[len=3].lower()': 'boy',
#   'prefix[len=4].lower()': 'boyc',
#   'prefix[len=5].lower()': 'boyco',
#   'suffix[len=3].lower()': 'ott',
#   'suffix[len=4].lower()': 'cott',
#   'suffix[len=5].lower()': 'ycott',
#   'alphanumeric': False,
#   'hasdash': False,
#   'shape': 'xxxxxxx',
#   'shapeshort': 'x'},
#  {'w[0]': 'British',
#   'w[1]': 'lamb',
#   'w[-1]': 'boycott',
#   'w[0].lower()': 'british',
#   'w[1].lower()': 'lamb',
#   'w[-1].lower()': 'boycott',
#   'prefix[len=3]': 'Bri',
#   'prefix[len=4]': 'Brit',
#   'prefix[len=5]': 'Briti',
#   'suffix[len=3]': 'ish',
#   'suffix[len=4]': 'tish',
#   'suffix[len=5]': 'itish',
#   'prefix[len=3].lower()': 'bri',
#   'prefix[len=4].lower()': 'brit',
#   'prefix[len=5].lower()': 'briti',
#   'suffix[len=3].lower()': 'ish',
#   'suffix[len=4].lower()': 'tish',
#   'suffix[len=5].lower()': 'itish',
#   'alphanumeric': False,
#   'hasdash': False,
#   'shape': 'Xxxxxxx',
#   'shapeshort': 'Xx'},
#  {'w[0]': 'lamb',
#   'w[1]': '.',
#   'w[-1]': 'British',
#   'w[0].lower()': 'lamb',
#   'w[1].lower()': '.',
#   'w[-1].lower()': 'british',
#   'prefix[len=3]': 'lam',
#   'prefix[len=4]': 'lamb',
#   'prefix[len=5]': 'lamb',
#   'suffix[len=3]': 'amb',
#   'suffix[len=4]': 'lamb',
#   'suffix[len=5]': 'lamb',
#   'prefix[len=3].lower()': 'lam',
#   'prefix[len=4].lower()': 'lamb',
#   'prefix[len=5].lower()': 'lamb',
#   'suffix[len=3].lower()': 'amb',
#   'suffix[len=4].lower()': 'lamb',
#   'suffix[len=5].lower()': 'lamb',
#   'alphanumeric': False,
#   'hasdash': False,
#   'shape': 'xxxx',
#   'shapeshort': 'x'},
#  {'w[0]': '.',
#   'w[1]': '</S>',
#   'w[-1]': 'lamb',
#   'w[0].lower()': '.',
#   'w[-1].lower()': 'lamb',
#   'prefix[len=3]': '.',
#   'prefix[len=4]': '.',
#   'prefix[len=5]': '.',
#   'suffix[len=3]': '.',
#   'suffix[len=4]': '.',
#   'suffix[len=5]': '.',
#   'prefix[len=3].lower()': '.',
#   'prefix[len=4].lower()': '.',
#   'prefix[len=5].lower()': '.',
#   'suffix[len=3].lower()': '.',
#   'suffix[len=4].lower()': '.',
#   'suffix[len=5].lower()': '.',
#   'alphanumeric': False,
#   'hasdash': False,
#   'shape': '.',
#   'shapeshort': '.'}]

# %%
import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics

def perform(ctrain_X,ctrain_Y,ctest_X,ctest_Y):
    #print("in")
    crf = sklearn_crfsuite.CRF(
        algorithm='lbfgs', # default; Gradient descent using the L-BFGS method
        min_freq=5, # the minimum freq of a feature in the training set
        max_iterations=100, # set this value to stop the training after k epochs
    )

    # train a CRF model on the training set
    try:
        crf.fit(ctrain_X, ctrain_Y)
    except AttributeError:
        pass
    #print("inside")
    cY_pred = crf.predict(ctest_X)
    cY_pred = transform_label(cY_pred)
    ctest_Y = transform_label(ctest_Y)
    a = eval(ctest_Y, cY_pred, "LOC")
    b = eval(ctest_Y, cY_pred, "PER")
    print(a,b)

# %%
#c_hum = transform_human(cY_pred)
#ctest_human = transform_human(ctest_Y)
# Out:
# [['O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O', 'O', 'O'],
#  ['B-PER', 'I-PER'],
#  ['B-LOC', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O'],
#  ['O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O'],
#  ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-LOC',
#   'O',
#   'B-LOC',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'B-PER', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['B-LOC', 'O', 'B-PER', 'I-PER'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O'],
#  ['B-PER', 'I-PER', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER'],
#  ['O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'B-LOC', 'O'],
#  ['B-LOC', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O'],
#  ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O'],
#  ['B-PER', 'O', 'O', 'O'],
#  ['O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O'],
#  ['O', 'B-MISC', 'I-MISC', 'O', 'O', 'O'],
#  ['B-LOC', 'O', 'B-LOC', 'O'],
#  ['O', 'O', 'O', 'B-MISC', 'I-MISC'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'O'],
#  ['O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['B-LOC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O'],
#  ['B-LOC', 'O', 'B-PER', 'I-PER', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['B-LOC', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'B-PER', 'I-PER', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'B-LOC', 'O', 'B-LOC', 'I-LOC', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'B-MISC', 'O'],
#  ['B-LOC', 'O', 'B-LOC', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'B-LOC', 'O', 'B-LOC', 'I-LOC'],
#  ['O', 'O', 'O'],
#  ['B-LOC'],
#  ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'O', 'O'],
#  ['B-PER', 'I-PER', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'I-LOC', 'O'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O'],
#  ['B-PER', 'I-PER', 'O', 'O'],
#  ['O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O'],
#  ['O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC'],
#  ['B-MISC', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'B-ORG', 'O'],
#  ['O', 'O', 'B-PER', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['B-MISC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O'],
#  ['B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O'],
#  ['O', 'O', 'B-ORG', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['B-ORG',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-ORG',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'B-MISC', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'B-MISC'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['B-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'B-PER', 'O', 'O', 'B-PER', 'O', 'O'],
#  ['B-PER', 'I-PER'],
#  ['B-LOC', 'O'],
#  ['O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-PER',
#   'I-PER',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O'],
#  ['O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O'],
#  ['O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O'],
#  ['O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-LOC',
#   'O',
#   'B-LOC',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O'],
#  ['O', 'O'],
#  ['B-ORG',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O'],
#  ['O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'I-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O'],
#  ['B-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O'],
#  ['B-LOC', 'O'],
#  ['B-LOC', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O'],
#  ['O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER'],
#  ['O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'B-MISC',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O', 'O', 'B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O'],
#  ['B-ORG'],
#  ['O', 'O', 'B-MISC', 'O', 'O', 'O'],
#  ['B-LOC', 'I-LOC', 'I-LOC', 'O'],
#  ['O', 'O', 'B-MISC'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'B-ORG', 'O'],
#  ['B-ORG', 'O', 'B-ORG', 'I-ORG', 'O'],
#  ['O', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'O'],
#  ['B-PER', 'I-PER'],
#  ['B-LOC', 'O'],
#  ['B-LOC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O'],
#  ['B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O'],
#  ['O', 'O', 'B-LOC', 'O', 'B-LOC', 'I-LOC', 'B-MISC', 'I-MISC', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['O', 'O', 'O', 'B-MISC', 'I-MISC'],
#  ['O', 'O', 'O', 'O', 'B-LOC', 'O', 'B-LOC', 'I-LOC', 'O', 'O', 'O'],
#  ['B-LOC', 'I-LOC'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'O', 'O'],
#  ['B-PER', 'I-PER', 'O', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'O', 'O'],
#  ['B-PER', 'I-PER', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O'],
#  ['B-PER', 'O', 'O', 'B-PER', 'O', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'O'],
#  ['B-PER', 'I-PER', 'O', 'O'],
#  ['B-LOC'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'O', 'O'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'B-LOC', 'O', 'B-LOC', 'I-LOC', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['B-LOC',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'B-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O'],
#  ['B-LOC', 'O'],
#  ['B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'B-MISC', 'I-MISC', 'O', 'O'],
#  ['B-LOC', 'O', 'B-LOC', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-LOC',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O'],
#  ['O', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['B-LOC',
#   'I-LOC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O'],
#  ['B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O'],
#  ['O', 'O', 'B-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['B-LOC', 'I-LOC', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['B-LOC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O'],
#  ['B-LOC',
#   'I-LOC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['B-PER',
#   'I-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER'],
#  ['B-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'I-PER'],
#  ['O', 'B-LOC', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O'],
#  ['O'],
#  ['O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'I-MISC',
#   'I-MISC',
#   'I-MISC',
#   'O'],
#  ['B-LOC', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'I-MISC',
#   'I-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'I-LOC', 'O'],
#  ['O', 'O', 'B-ORG', 'I-ORG'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['B-MISC', 'I-MISC'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'B-ORG', 'I-ORG'],
#  ['B-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'I-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'B-MISC', 'O'],
#  ['B-LOC', 'I-LOC', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O'],
#  ['O'],
#  ['O', 'O', 'B-ORG', 'I-ORG'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'B-ORG', 'O'],
#  ['B-ORG', 'O', 'B-ORG', 'I-ORG', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'B-ORG', 'O'],
#  ['B-ORG', 'O', 'B-ORG', 'I-ORG', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'B-ORG', 'I-ORG', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-LOC', 'O', 'O', 'O', 'O', 'B-LOC', 'I-LOC', 'O', 'B-LOC', 'O'],
#  ['O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-ORG',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'I-LOC', 'O'],
#  ['O', 'O', 'B-ORG'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['B-LOC', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'I-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'B-LOC', 'I-LOC'],
#  ['B-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'B-LOC', 'I-LOC'],
#  ['B-ORG', 'O', 'B-LOC', 'I-LOC'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'I-LOC', 'O'],
#  ['B-ORG', 'I-ORG', 'I-ORG'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-MISC', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'B-ORG'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['B-MISC', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'B-LOC', 'I-LOC'],
#  ['B-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'I-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'B-LOC', 'I-LOC'],
#  ['B-ORG', 'I-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'B-LOC', 'I-LOC'],
#  ['B-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'I-ORG', 'O', 'B-LOC', 'I-LOC'],
#  ['B-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'B-LOC', 'I-LOC'],
#  ['B-ORG', 'O', 'B-LOC'],
#  ['O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'B-LOC'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'I-LOC', 'O'],
#  ['O', 'O', 'B-ORG', 'B-LOC'],
#  ['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'B-ORG', 'O'],
#  ['B-ORG', 'O', 'B-MISC', 'I-MISC', 'O', 'B-PER', 'O', 'O', 'B-MISC'],
#  ['I-MISC', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-ORG',
#   'O'],
#  ['O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O'],
#  ['O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['O', 'O', 'B-MISC', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
# ...
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'B-LOC', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-ORG',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'B-MISC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER', 'O', 'B-MISC', 'O', 'B-PER', 'O', 'O', 'O'],
#  ['B-PER', 'I-PER'],
#  ['B-LOC', 'O'],
#  ['B-LOC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-ORG',
#   'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'B-ORG',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O'],
#  ['O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-LOC',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'B-ORG', 'I-ORG', 'O', 'O'],
#  ['B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-LOC',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'B-ORG', 'I-ORG', 'O'],
#  ['B-LOC', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O'],
#  ['B-PER', 'I-PER'],
#  ['B-LOC', 'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'I-MISC',
#   'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'I-MISC',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'B-PER', 'O', 'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-PER', 'I-PER'],
#  ['B-LOC', 'O'],
#  ['B-MISC',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'I-PER',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-LOC',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'B-ORG',
#   'O',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O'],
#  ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O'],
#  ...]

# %%
#from sklearn_crfsuite.utils import flatten

#y_true_flat = flatten(ctest_human)
#y_pred_flat = flatten(c_hum)
x = ["B-PER",'I-PER',"B-LOC",'I-LOC']
for label in x:
    print( label, metrics.flat_f1_score(ctest_Y, cY_pred, average='weighted', labels=label) )
    print( label, metrics.flat_precision_score(ctest_Y, cY_pred, average='weighted', labels=label) )
    print( label, metrics.flat_recall_score(ctest_Y, cY_pred, average='weighted', labels=label) )
# Out:
# B-PER 0.8090715535236194
# B-PER 0.8226583625448578
# B-PER 0.7976291278577476
# I-PER 0.832318866428076
# I-PER 0.8376584062142055
# I-PER 0.8293650793650794
# B-LOC 0.8090715535236194
# B-LOC 0.8226583625448578
# B-LOC 0.7976291278577476
# I-LOC 0.8090715535236193
# I-LOC 0.822658362544858
# I-LOC 0.7976291278577476

# %%
# Out:
# {'Precision (LOC)': 0.8478787878787879,
#  'Recall (LOC)': 0.8387290167865707,
#  'F1 (LOC)': 0.8432790837854129}
